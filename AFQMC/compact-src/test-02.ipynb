# %%
from initialization import * 
from functions import *

# %%
measurement_flag = 0
E = 0
W = 0
n_equilibrium_blocks = 1
n_block_steps = 1

# %%
## equilibration phase

for i_block in range(n_equilibrium_blocks):
    for j_step in range(n_block_steps):
        Phi, w, O, E, W = step_walk(Phi, n_walkers, n_sites, weights, overlaps, E, W, K, K_half_projector, measurement_flag, Phi_t, n_elec_up, n_particles, U, fac_norm, auxiliary_field)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 5
#       3 for i_block in range(n_equilibrium_blocks):
#       4     for j_step in range(n_block_steps):
# ----> 5         Phi, w, O, E, W = step_walk(Phi, n_walkers, n_sites, weights, overlaps, E, W, K, K_half_projector, measurement_flag, Phi_t, n_elec_up, n_particles, U, fac_norm, auxiliary_field)
#
# TypeError: cannot unpack non-iterable NoneType object
