# %%
import numpy as np

# %%
H = [[0, -1, 0, 0], [-1, 0, -1, 0], [0, -1, 0, -1], [0, 0, -1, 0]]

evals, evecs = np.linalg.eig(H)

# %%
evals
# Out:
# array([-1.61803399, -0.61803399,  1.61803399,  0.61803399])

# %%
evecs[:, 0]
# Out:
# array([0.37174803, 0.60150096, 0.60150096, 0.37174803])

# %%
evecs[:, 1]
# Out:
# array([-0.60150096, -0.37174803,  0.37174803,  0.60150096])

# %%
evecs[:, 2]
# Out:
# array([-0.37174803,  0.60150096, -0.60150096,  0.37174803])

# %%
evecs[:, 3]
# Out:
# array([ 0.60150096, -0.37174803, -0.37174803,  0.60150096])
